# %%
import tweepy as tw

# %%
consumer_api_key = "3VbKOgmaGoh9lXqrfBWDRWIVH"
consumer_api_secret_key = "k21iNXSwyDy628VG6J4Gieec91wyxAS5fG5fOohgSMn7OniYin"
access_token = "4732473492-9VcLpbnxyRIWzGggwNXApcD4QIRf2bV1aCO2pwC"
access_token_secret = "J6ZMnQ874dREaXadm2ksdLI9IHa4xoaCHe1Nghvf3C9Tf"

# %%
search_words = "#wildfires"
date_since = "2018-11-16"

# %%
auth = tw.OAuthHandler(consumer_api_key, consumer_api_secret_key)
auth.set_access_token(access_token, access_token_secret)
api = tw.API(auth, wait_on_rate_limit=True)

# %%
tweets = tw.Cursor(api.search,
              q=search_words,
              lang="en",
              since=date_since, tweet_mode="extended").items(5)
tweets

# %%
import json
import pandas as pd

# %%
pd.set_option('display.max_colwidth', 10)

# %%
json_data = [r._json for r in tweets]

# %%
df = pd.io.json.json_normalize(json_data)

# %%
df.columns.to_list()
# Out:
# ['created_at',
#  'id',
#  'id_str',
#  'full_text',
#  'truncated',
#  'display_text_range',
#  'source',
#  'in_reply_to_status_id',
#  'in_reply_to_status_id_str',
#  'in_reply_to_user_id',
#  'in_reply_to_user_id_str',
#  'in_reply_to_screen_name',
#  'geo',
#  'coordinates',
#  'place',
#  'contributors',
#  'is_quote_status',
#  'retweet_count',
#  'favorite_count',
#  'favorited',
#  'retweeted',
#  'possibly_sensitive',
#  'lang',
#  'entities.hashtags',
#  'entities.symbols',
#  'entities.user_mentions',
#  'entities.urls',
#  'metadata.iso_language_code',
#  'metadata.result_type',
#  'user.id',
#  'user.id_str',
#  'user.name',
#  'user.screen_name',
#  'user.location',
#  'user.description',
#  'user.url',
#  'user.entities.url.urls',
#  'user.entities.description.urls',
#  'user.protected',
#  'user.followers_count',
#  'user.friends_count',
#  'user.listed_count',
#  'user.created_at',
#  'user.favourites_count',
#  'user.utc_offset',
#  'user.time_zone',
#  'user.geo_enabled',
#  'user.verified',
#  'user.statuses_count',
#  'user.lang',
#  'user.contributors_enabled',
#  'user.is_translator',
#  'user.is_translation_enabled',
#  'user.profile_background_color',
#  'user.profile_background_image_url',
#  'user.profile_background_image_url_https',
#  'user.profile_background_tile',
#  'user.profile_image_url',
#  'user.profile_image_url_https',
#  'user.profile_banner_url',
#  'user.profile_link_color',
#  'user.profile_sidebar_border_color',
#  'user.profile_sidebar_fill_color',
#  'user.profile_text_color',
#  'user.profile_use_background_image',
#  'user.has_extended_profile',
#  'user.default_profile',
#  'user.default_profile_image',
#  'user.following',
#  'user.follow_request_sent',
#  'user.notifications',
#  'user.translator_type',
#  'retweeted_status.created_at',
#  'retweeted_status.id',
#  'retweeted_status.id_str',
#  'retweeted_status.full_text',
#  'retweeted_status.truncated',
#  'retweeted_status.display_text_range',
#  'retweeted_status.entities.hashtags',
#  'retweeted_status.entities.symbols',
#  'retweeted_status.entities.user_mentions',
#  'retweeted_status.entities.urls',
#  'retweeted_status.entities.media',
#  'retweeted_status.extended_entities.media',
#  'retweeted_status.metadata.iso_language_code',
#  'retweeted_status.metadata.result_type',
#  'retweeted_status.source',
#  'retweeted_status.in_reply_to_status_id',
#  'retweeted_status.in_reply_to_status_id_str',
#  'retweeted_status.in_reply_to_user_id',
#  'retweeted_status.in_reply_to_user_id_str',
#  'retweeted_status.in_reply_to_screen_name',
#  'retweeted_status.user.id',
#  'retweeted_status.user.id_str',
#  'retweeted_status.user.name',
#  'retweeted_status.user.screen_name',
#  'retweeted_status.user.location',
#  'retweeted_status.user.description',
#  'retweeted_status.user.url',
#  'retweeted_status.user.entities.url.urls',
#  'retweeted_status.user.entities.description.urls',
#  'retweeted_status.user.protected',
#  'retweeted_status.user.followers_count',
#  'retweeted_status.user.friends_count',
#  'retweeted_status.user.listed_count',
#  'retweeted_status.user.created_at',
#  'retweeted_status.user.favourites_count',
#  'retweeted_status.user.utc_offset',
#  'retweeted_status.user.time_zone',
#  'retweeted_status.user.geo_enabled',
#  'retweeted_status.user.verified',
#  'retweeted_status.user.statuses_count',
#  'retweeted_status.user.lang',
#  'retweeted_status.user.contributors_enabled',
#  'retweeted_status.user.is_translator',
#  'retweeted_status.user.is_translation_enabled',
#  'retweeted_status.user.profile_background_color',
#  'retweeted_status.user.profile_background_image_url',
#  'retweeted_status.user.profile_background_image_url_https',
#  'retweeted_status.user.profile_background_tile',
#  'retweeted_status.user.profile_image_url',
#  'retweeted_status.user.profile_image_url_https',
#  'retweeted_status.user.profile_banner_url',
#  'retweeted_status.user.profile_link_color',
#  'retweeted_status.user.profile_sidebar_border_color',
#  'retweeted_status.user.profile_sidebar_fill_color',
#  'retweeted_status.user.profile_text_color',
#  'retweeted_status.user.profile_use_background_image',
#  'retweeted_status.user.has_extended_profile',
#  'retweeted_status.user.default_profile',
#  'retweeted_status.user.default_profile_image',
#  'retweeted_status.user.following',
#  'retweeted_status.user.follow_request_sent',
#  'retweeted_status.user.notifications',
#  'retweeted_status.user.translator_type',
#  'retweeted_status.geo',
#  'retweeted_status.coordinates',
#  'retweeted_status.place',
#  'retweeted_status.contributors',
#  'retweeted_status.is_quote_status',
#  'retweeted_status.retweet_count',
#  'retweeted_status.favorite_count',
#  'retweeted_status.favorited',
#  'retweeted_status.retweeted',
#  'retweeted_status.possibly_sensitive',
#  'retweeted_status.lang']

# %%
df1 = df[['created_at', 'full_text', 'user.name', 'user.location', 'geo', 'coordinates', 'place' , 'lang']]

# %%
df1
# Out:
#                        created_at  \
# 0  Wed Feb 19 13:09:17 +0000 2020
# 1  Wed Feb 19 12:49:47 +0000 2020
# 2  Wed Feb 19 12:49:42 +0000 2020
# 3  Wed Feb 19 12:18:44 +0000 2020
# 4  Wed Feb 19 11:29:29 +0000 2020
#
#                                            full_text                user.name  \
# 0  RT @CMINE_EU: Climate change as an enabler of ...                     PSCE
# 1  RT @RealPhatsBlog: RFS denies sacking voluntee...      Australian Elite 🇦🇺
# 2  RFS denies sacking volunteer firefighter Paul ...            PhatzNewsRoom
# 3  PG&amp;E banking on big profits after utility ...            PhatzNewsRoom
# 4  RT @roboticscats: Insight Globe Mobile app use...  Veerachai Chai Tanpipat
#
#        user.location   geo coordinates place lang
# 0  Brussels, Belgium  None        None  None   en
# 1          Melbourne  None        None  None   en
# 2      North America  None        None  None   en
# 3      North America  None        None  None   en
# 4  Bangkok, Thailand  None        None  None   en

# %%
df1['full_text'].tolist()
# Out:
# ['RT @CMINE_EU: Climate change as an enabler of #wildfires at the @DRIVER_PROJECT conference in Brussels. Join CMINE now and take part in dis…',
#  'RT @RealPhatsBlog: RFS denies sacking volunteer firefighter Paul Parker, who swore at Scott Morrison \n#Wildfires\n#Floods\n#Drought\n#Australi…',
#  'RFS denies sacking volunteer firefighter Paul Parker, who swore at Scott Morrison \n#Wildfires\n#Floods\n#Drought\n#Australia\n#NewSouthWales\n#GalapagosIslands\n#Sydney\n#Bushfires\n#CommissionerShaneFitzsimmons \n#StevenMarshall\n#PMScottMorrison\n#StateOfEmergency\nhttps://t.co/eQOzvMdTc4',
#  'PG&amp;E banking on big profits after utility leaves bankruptcy\n#Wildfires\n#California\n#LosAngeles\n#SantaClarita\n#SantaRosa\n#NapaValley\n#Evacuations\n#BillJohnson\n#KincadeFire\n#HillsideFire\n#MariaFire\n#SanFrancisco\n#CaveFire\n#PGE\nhttps://t.co/CTGm06BHxN',
#  'RT @roboticscats: Insight Globe Mobile app uses standard Google Map-like interface. Fire icons locate the #wildfires detected. Red fire ico…']

# %%
type(json_data)
# Out:
# list

# %%
json_data[0]
# Out:
# {'created_at': 'Thu Jan 16 12:15:24 +0000 2020',
#  'id': 1217782402233389056,
#  'id_str': '1217782402233389056',
#  'full_text': 'RT @earthstartsbeat: The effect of the #Australia #WildFires is visible in the December L3 maps released by ESB (https://t.co/2mSHjmnKfx).…',
#  'truncated': False,
#  'display_text_range': [0, 139],
#  'entities': {'hashtags': [{'text': 'Australia', 'indices': [39, 49]},
#    {'text': 'WildFires', 'indices': [50, 60]}],
#   'symbols': [],
#   'user_mentions': [{'screen_name': 'earthstartsbeat',
#     'name': 'earthstartsbeating',
#     'id': 855017978429149184,
#     'id_str': '855017978429149184',
#     'indices': [3, 19]}],
#   'urls': [{'url': 'https://t.co/2mSHjmnKfx',
#     'expanded_url': 'https://lnkd.in/gMvKBZM',
#     'display_url': 'lnkd.in/gMvKBZM',
#     'indices': [113, 136]}]},
#  'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#  'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'in_reply_to_screen_name': None,
#  'user': {'id': 2811521279,
#   'id_str': '2811521279',
#   'name': 'Alexey Kucheiko',
#   'screen_name': 'Alexindia1',
#   'location': '',
#   'description': '',
#   'url': None,
#   'entities': {'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 15,
#   'friends_count': 106,
#   'listed_count': 0,
#   'created_at': 'Mon Oct 06 20:50:24 +0000 2014',
#   'favourites_count': 542,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': False,
#   'statuses_count': 358,
#   'lang': None,
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'C0DEED',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1147412819706601472/JxvNY_li_normal.png',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1147412819706601472/JxvNY_li_normal.png',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2811521279/1562399469',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': True,
#   'default_profile': True,
#   'default_profile_image': False,
#   'following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'none'},
#  'geo': None,
#  'coordinates': None,
#  'place': None,
#  'contributors': None,
#  'retweeted_status': {'created_at': 'Thu Jan 16 10:34:53 +0000 2020',
#   'id': 1217757104821489665,
#   'id_str': '1217757104821489665',
#   'full_text': 'The effect of the #Australia #WildFires is visible in the December L3 maps released by ESB (https://t.co/2mSHjmnKfx). This animation shows the high values of #Formaldehyde and #CarbonMonoxide impacting the quality of the air. @CopernicusEU data are processed on @ondadias https://t.co/PFCIyIcBVy',
#   'truncated': False,
#   'display_text_range': [0, 271],
#   'entities': {'hashtags': [{'text': 'Australia', 'indices': [18, 28]},
#     {'text': 'WildFires', 'indices': [29, 39]},
#     {'text': 'Formaldehyde', 'indices': [158, 171]},
#     {'text': 'CarbonMonoxide', 'indices': [176, 191]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'CopernicusEU',
#      'name': 'Copernicus EU',
#      'id': 978604706,
#      'id_str': '978604706',
#      'indices': [226, 239]},
#     {'screen_name': 'ondadias',
#      'name': 'ONDA DIAS',
#      'id': 1000335446721875968,
#      'id_str': '1000335446721875968',
#      'indices': [262, 271]}],
#    'urls': [{'url': 'https://t.co/2mSHjmnKfx',
#      'expanded_url': 'https://lnkd.in/gMvKBZM',
#      'display_url': 'lnkd.in/gMvKBZM',
#      'indices': [92, 115]}],
#    'media': [{'id': 1217757093719171072,
#      'id_str': '1217757093719171072',
#      'indices': [272, 295],
#      'media_url': 'http://pbs.twimg.com/tweet_video_thumb/EOZXn_HX4AACbTO.jpg',
#      'media_url_https': 'https://pbs.twimg.com/tweet_video_thumb/EOZXn_HX4AACbTO.jpg',
#      'url': 'https://t.co/PFCIyIcBVy',
#      'display_url': 'pic.twitter.com/PFCIyIcBVy',
#      'expanded_url': 'https://twitter.com/earthstartsbeat/status/1217757104821489665/photo/1',
#      'type': 'photo',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'small': {'w': 680, 'h': 361, 'resize': 'fit'},
#       'medium': {'w': 1200, 'h': 636, 'resize': 'fit'},
#       'large': {'w': 1908, 'h': 1012, 'resize': 'fit'}}}]},
#   'extended_entities': {'media': [{'id': 1217757093719171072,
#      'id_str': '1217757093719171072',
#      'indices': [272, 295],
#      'media_url': 'http://pbs.twimg.com/tweet_video_thumb/EOZXn_HX4AACbTO.jpg',
#      'media_url_https': 'https://pbs.twimg.com/tweet_video_thumb/EOZXn_HX4AACbTO.jpg',
#      'url': 'https://t.co/PFCIyIcBVy',
#      'display_url': 'pic.twitter.com/PFCIyIcBVy',
#      'expanded_url': 'https://twitter.com/earthstartsbeat/status/1217757104821489665/photo/1',
#      'type': 'animated_gif',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'small': {'w': 680, 'h': 361, 'resize': 'fit'},
#       'medium': {'w': 1200, 'h': 636, 'resize': 'fit'},
#       'large': {'w': 1908, 'h': 1012, 'resize': 'fit'}},
#      'video_info': {'aspect_ratio': [477, 253],
#       'variants': [{'bitrate': 0,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/tweet_video/EOZXn_HX4AACbTO.mp4'}]}}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 855017978429149184,
#    'id_str': '855017978429149184',
#    'name': 'earthstartsbeating',
#    'screen_name': 'earthstartsbeat',
#    'location': 'Roma, Lazio',
#    'description': 'About every corner of the Earth with the eyes of Sentinels satellites. Chronicles and portraits in the framework of the Earth Observation.',
#    'url': 'https://t.co/6asVOscnYk',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/6asVOscnYk',
#        'expanded_url': 'https://earthstartsbeating.com/',
#        'display_url': 'earthstartsbeating.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 804,
#    'friends_count': 677,
#    'listed_count': 24,
#    'created_at': 'Thu Apr 20 11:19:06 +0000 2017',
#    'favourites_count': 493,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 150,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/855019503046066176/P4pmEC8M_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/855019503046066176/P4pmEC8M_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/855017978429149184/1492688957',
#    'profile_link_color': '1B95E0',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 12,
#   'favorite_count': 18,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  'is_quote_status': False,
#  'retweet_count': 12,
#  'favorite_count': 0,
#  'favorited': False,
#  'retweeted': False,
#  'possibly_sensitive': False,
#  'lang': 'en'}

# %%
import tweepy as tw
import json
import pandas as pd



def pullTweets(hasTagWord, searchStartDate, maxNoOfTweets):
    print(hasTagWord, searchStartDate, maxNoOfTweets)
    consumer_api_key = "3VbKOgmaGoh9lXqrfBWDRWIVH"
    consumer_api_secret_key = "k21iNXSwyDy628VG6J4Gieec91wyxAS5fG5fOohgSMn7OniYin"
    access_token = "4732473492-9VcLpbnxyRIWzGggwNXApcD4QIRf2bV1aCO2pwC"
    access_token_secret = "J6ZMnQ874dREaXadm2ksdLI9IHa4xoaCHe1Nghvf3C9Tf"

    auth = tw.OAuthHandler(consumer_api_key, consumer_api_secret_key)
    auth.set_access_token(access_token, access_token_secret)
    api = tw.API(auth, wait_on_rate_limit=True)

    tweets = tw.Cursor(api.search,
                  q=hasTagWord,
                  lang="en",
                  since=searchStartDate, tweet_mode="extended").items(int(maxNoOfTweets))
    print(tweets)
    json_data = [r._json for r in tweets]
    df = pd.io.json.json_normalize(json_data)
    #df1 = df[['created_at', 'full_text', 'user.name', 'user.location', 'geo', 'coordinates', 'place' , 'lang']]
    text = df['full_text'].tolist()
    return text


hasTagWord, searchStartDate, maxNoOfTweets  = 'Trump', '2020-02-01', '10'
pullTweets (hasTagWord, searchStartDate, maxNoOfTweets)
# Out:
# Trump 2020-02-01 10
# <tweepy.cursor.ItemIterator object at 0x0000027862A252B0>
# ['RT @tedlieu: The @realDonaldTrump budget makes cuts to the Centers for Disease Control and Prevention. @GOP supports whatever Trump wants n…',
#  "RT @washingtonpost: Analysis: Trump's 36 hours in India https://t.co/YzgAXRnj2a",
#  'RT @Mikah_Avi: @mmpadellan Did anyone know that Epstein had Bloomberg’s name in his blackbook? They had to be BFFs just like Trump &amp; Epstei…',
#  'RT @JRubinBlogger: His solution to passing something near impossible to achieve is to aim for something entirely impossible (term limits).…',
#  'RT @faiza_n_ali: Modi and Trump are cut from the same cloth. Violence between Hindus and Muslims fanned by Modi is unfolding in India and b…',
#  'RT @MaryMargOlohan: Doctors offered to abort her. Her mother said no. \n\nNow Marin says she’s “happy to be alive.”\n\n“It just pains me that s…',
#  "RT @ritholtz: The mother of all bailouts:\n \nPresident Trump's trade-related payments to American farmers now is &gt; $28 billion + rising. \n\nT…",
#  'RT @noseyrosey333: Yes, I loved it.......Jim Acosta is a hero again!!! Traitor Trump is so phony &amp; corrupt!!',
#  "RT @BJS_quire: Nice to see a Trump at a Taj Mahal they haven't bankrupted. https://t.co/CPozW5sqUU",
#  'RT @jamisonfoser: Clarence Thomas’s wife is running around making revenge lists to help purge the government of people who aren’t loyal to…']
