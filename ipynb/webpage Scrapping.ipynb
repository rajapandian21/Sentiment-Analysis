# %%
import requests
from bs4 import BeautifulSoup

def getNews(lang):
    newsList = []
    googleNews = "news.google.com"
    url = "https://news.google.com/?hl=" + lang + "-IN&gl=IN&ceid=IN:"+lang
    if googleNews in url:
        result = requests.get(url)
        if result.status_code == 200:
            src = result.content
            soup = BeautifulSoup(src, 'lxml')
            links = soup.find_all(["h3","h4"])
            for link in links:
                if link.find('a'):
                    aLink = link.find('a')
                    if len(aLink.text) > 0:
                        newsList.append(aLink.text)

        else:
            print('Page is unavailabe')
    else:
        print('Invalid URL')
    return newsList

# %%
from googletrans import Translator

# %%
translator = Translator()

# %%
newsEn = translator.translate(news)

# %%
newsEn = [ x.text for x in newsEn ]

# %%
newsEn
# Out:
# ['CAA, NPR, enarci resistant to 5-th day of a continuing struggle',
#  'CAA struggle: Washermanpet What happened? - Council pottutaitta CM',
#  "Resident resolution against the amendment: MK Stalin's request rejection",
#  'Battleground Archives Washermanpet CAA will continue to fight Islamist couple married ..',
#  "CAA: porattakkarankala false propaganda about Stalin's accusation against AIADMK ceyranka ...",
#  'Even., Vodafone- mutuvatutan only way to drag-Vodafone prominent person public talk tomorrow',
#  'When the remaining amount of Rs 10,000 crore will be due to be paid Airtel ... ..?',
#  'Vodafone offer outstanding amount of Rs 2,500 crore approved by the agency Idea',
#  'PROBLEM peak in the Vodafone: a., A little kotukkurom itamilla the talk!',
#  '2,500 crores only? Vodafone Request Supreme Court dismisses: Airtel pays Rs 10,000 crore',
#  'In Japan, 99 people were stationed aboard the Corona effect',
# ...

# %%
news
# Out:
# ['சிஏஏ, என்பிஆர், என்ஆர்சிக்கு எதிர்ப்பு ;5 -வது நாளாக தொடரும் போராட்டம்',
#  'CAA போராட்டம்: வண்ணாரப்பேட்டையில் நடந்தது என்ன? - சபையில் போட்டுடைத்த முதல்வர்',
#  'குடியுரிமை திருத்தச் சட்டத்திற்கு எதிராக தீர்மானம்: மு.க. ஸ்டாலின் கோரிக்கை நிராகரிப்பு',
#  'சென்னை வண்ணாரப்பேட்டை சிஏஏ போராட்டக் களத்தில் இஸ்லாமிய ஜோடிக்கு திருமணம்.. தொடரும் போராட்டம்',
#  'CAA: போராட்டக்காரங்கள பத்தி பொய்ப் பிரசாரம் செய்றாங்க... அதிமுக மீது ஸ்டாலின் குற்றச்சாட்டு',
#  'இப்படி சொன்னால்.,Vodafone-ஐ நாளையே இழுத்து மூடுவதுதான் ஒரேவழி-வோடபோன் முக்கிய நபர் பகிரங்க பேச்சு',
#  'ரூ.10,000 கோடி நிலுவைத் தொகையை செலுத்தியது ஏர்டெல்... மீதி தொகை எப்போது செலுத்துகிறது..?',
#  'நிலுவை தொகையில் ரூ.2,500 கோடி வழங்க வோடபோன் ஐடியா நிறுவனம் ஒப்புதல்',
#  'உச்சக்கட்ட பிரச்னையில் Vodafone: கொஞ்சம்., கொஞ்சமா கொடுக்குறோம்- அந்த பேச்சுக்கே இடமில்ல!',
#  '2,500 crores only? Vodafone Request Supreme Court dismisses: Airtel pays Rs 10,000 crore',
#  'ஜப்பானில் நிறுத்தப்பட்டுள்ள கப்பலில் மேலும் 99 பேருக்கு கொரோனா பாதிப்பு',
# ...
